# %% [markdown]
# # solopy calibration example

# %%
import solopy
import logging
from ccdproc import ImageFileCollection
from pathlib import Path

# %%
# Observation date (=subdirectory name)
subdir = "2025_0803" 

# Data directory
WORKDIR = Path("../solo-data")

# Lv0 data directory
LV0DIR = WORKDIR/"Lv0"
LV0_subdir = LV0DIR / subdir

# Lv1 data directory
LV1DIR = WORKDIR/"Lv1"
LV1_subdir = LV1DIR / subdir

# Master calibration files directory
MASTERDIR = WORKDIR / "calibration_files"

# Log directory
LOGDIR = WORKDIR/"log"
LOGDIR.mkdir(parents=True, exist_ok=True)
fpath_log = LOGDIR/f'solopy_{subdir}.log' # general log file path
if fpath_log.exists():
    fpath_log.unlink()

# %% [markdown]
# ### FitsLv0 (update header information)

# %%
allfits = ImageFileCollection(LV0_subdir, glob_include="*.fits")

# %%
lv0 = solopy.FitsLv0(log_file=fpath_log)

for fpath_fits in allfits.files_filtered(include_path=True):
    lv0.update_header(fpath_fits)
# Out:
# 2025-11-29 01:22:59,317 [INFO] Updated FitsLv0 header: bias_001.fits
# 2025-11-29 01:22:59,395 [INFO] Updated FitsLv0 header: bias_002.fits
# 2025-11-29 01:22:59,471 [INFO] Updated FitsLv0 header: bias_003.fits
# 2025-11-29 01:22:59,550 [INFO] Updated FitsLv0 header: bias_004.fits
# 2025-11-29 01:22:59,627 [INFO] Updated FitsLv0 header: bias_005.fits
# 2025-11-29 01:22:59,703 [INFO] Updated FitsLv0 header: bias_006.fits
# 2025-11-29 01:22:59,781 [INFO] Updated FitsLv0 header: bias_007.fits
# 2025-11-29 01:22:59,853 [INFO] Updated FitsLv0 header: bias_008.fits
# 2025-11-29 01:22:59,931 [INFO] Updated FitsLv0 header: bias_009.fits
# 2025-11-29 01:23:00,006 [INFO] Updated FitsLv0 header: dark180_001.fits
# 2025-11-29 01:23:00,085 [INFO] Updated FitsLv0 header: dark180_002.fits
# 2025-11-29 01:23:00,157 [INFO] Updated FitsLv0 header: dark180_003.fits
# 2025-11-29 01:23:00,239 [INFO] Updated FitsLv0 header: dark180_004.fits
# 2025-11-29 01:23:00,317 [INFO] Updated FitsLv0 header: dark180_005.fits
# 2025-11-29 01:23:00,397 [INFO] Updated FitsLv0 header: dark180_006.fits
# 2025-11-29 01:23:00,478 [INFO] Updated FitsLv0 header: dark180_007.fits
# 2025-11-29 01:23:00,550 [INFO] Updated FitsLv0 header: dark180_008.fits
# 2025-11-29 01:23:00,630 [INFO] Updated FitsLv0 header: dark180_009.fits
# 2025-11-29 01:23:00,704 [INFO] Updated FitsLv0 header: eclplane_001_20250803085133.fits
# 2025-11-29 01:23:00,811 [INFO] Updated FitsLv0 header: eclplane_002_20250803085435.fits
# 2025-11-29 01:23:00,894 [INFO] Updated FitsLv0 header: eclplane_003_20250803085737.fits
# 2025-11-29 01:23:00,968 [INFO] Updated FitsLv0 header: eclplane_004_20250803090039.fits
# 2025-11-29 01:23:01,042 [INFO] Updated FitsLv0 header: eclplane_005_20250803090341.fits
# 2025-11-29 01:23:01,122 [INFO] Updated FitsLv0 header: eclplane_006_20250803090643.fits
# 2025-11-29 01:23:01,204 [INFO] Updated FitsLv0 header: eclplane_007_20250803090945.fits
# 2025-11-29 01:23:01,287 [INFO] Updated FitsLv0 header: eclplane_008_20250803091247.fits
# 2025-11-29 01:23:01,370 [INFO] Updated FitsLv0 header: eclplane_009_20250803091549.fits
# 2025-11-29 01:23:01,448 [INFO] Updated FitsLv0 header: eclplane_010_20250803091851.fits
# 2025-11-29 01:23:01,526 [INFO] Updated FitsLv0 header: eclplane_011_20250803092153.fits
# 2025-11-29 01:23:01,608 [INFO] Updated FitsLv0 header: eclplane_012_20250803092455.fits
# 2025-11-29 01:23:01,688 [INFO] Updated FitsLv0 header: eclplane_013_20250803092757.fits
# 2025-11-29 01:23:01,766 [INFO] Updated FitsLv0 header: eclplane_014_20250803093059.fits
# 2025-11-29 01:23:01,848 [INFO] Updated FitsLv0 header: eclplane_015_20250803093401.fits
# 2025-11-29 01:23:01,928 [INFO] Updated FitsLv0 header: eclplane_016_20250803093703.fits
# 2025-11-29 01:23:02,009 [INFO] Updated FitsLv0 header: eclplane_017_20250803094005.fits
# 2025-11-29 01:23:02,091 [INFO] Updated FitsLv0 header: eclplane_018_20250803094307.fits
# 2025-11-29 01:23:02,171 [INFO] Updated FitsLv0 header: eclplane_019_20250803094610.fits
# 2025-11-29 01:23:02,254 [INFO] Updated FitsLv0 header: eclplane_020_20250803094912.fits
# 2025-11-29 01:23:02,334 [INFO] Updated FitsLv0 header: eclplane_021_20250803095214.fits
# 2025-11-29 01:23:02,413 [INFO] Updated FitsLv0 header: eclplane_022_20250803095516.fits
# 2025-11-29 01:23:02,490 [INFO] Updated FitsLv0 header: eclplane_023_20250803095818.fits
# 2025-11-29 01:23:02,569 [INFO] Updated FitsLv0 header: eclplane_024_20250803100121.fits
# 2025-11-29 01:23:02,651 [INFO] Updated FitsLv0 header: eclplane_025_20250803100422.fits
# 2025-11-29 01:23:02,725 [INFO] Updated FitsLv0 header: eclplane_026_20250803100725.fits
# 2025-11-29 01:23:02,806 [INFO] Updated FitsLv0 header: eclplane_027_20250803101027.fits
# 2025-11-29 01:23:02,887 [INFO] Updated FitsLv0 header: eclplane_028_20250803101329.fits
# 2025-11-29 01:23:02,966 [INFO] Updated FitsLv0 header: eclplane_029_20250803101631.fits
# 2025-11-29 01:23:03,044 [INFO] Updated FitsLv0 header: eclplane_030_20250803101933.fits
# 2025-11-29 01:23:03,121 [INFO] Updated FitsLv0 header: eclplane_031_20250803102235.fits
# 2025-11-29 01:23:03,193 [INFO] Updated FitsLv0 header: eclplane_032_20250803102537.fits
# 2025-11-29 01:23:03,266 [INFO] Updated FitsLv0 header: eclplane_033_20250803102840.fits
# 2025-11-29 01:23:03,344 [INFO] Updated FitsLv0 header: eclplane_034_20250803103142.fits
# 2025-11-29 01:23:03,424 [INFO] Updated FitsLv0 header: eclplane_035_20250803103444.fits
# 2025-11-29 01:23:03,498 [INFO] Updated FitsLv0 header: eclplane_036_20250803103745.fits
# 2025-11-29 01:23:03,588 [INFO] Updated FitsLv0 header: eclplane_037_20250803104048.fits
# 2025-11-29 01:23:03,668 [INFO] Updated FitsLv0 header: eclplane_038_20250803104349.fits
# 2025-11-29 01:23:03,750 [INFO] Updated FitsLv0 header: eclplane_039_20250803104651.fits
# 2025-11-29 01:23:03,833 [INFO] Updated FitsLv0 header: eclplane_040_20250803104953.fits
# 2025-11-29 01:23:03,917 [INFO] Updated FitsLv0 header: eclplane_041_20250803105256.fits
# 2025-11-29 01:23:04,000 [INFO] Updated FitsLv0 header: eclplane_042_20250803105557.fits
# 2025-11-29 01:23:04,082 [INFO] Updated FitsLv0 header: eclplane_043_20250803105859.fits
# 2025-11-29 01:23:04,166 [INFO] Updated FitsLv0 header: eclplane_044_20250803110201.fits
# 2025-11-29 01:23:04,251 [INFO] Updated FitsLv0 header: eclplane_045_20250803110503.fits
# 2025-11-29 01:23:04,334 [INFO] Updated FitsLv0 header: eclplane_046_20250803110805.fits
# 2025-11-29 01:23:04,419 [INFO] Updated FitsLv0 header: eclplane_047_20250803111107.fits
# 2025-11-29 01:23:04,504 [INFO] Updated FitsLv0 header: eclplane_048_20250803111409.fits
# 2025-11-29 01:23:04,590 [INFO] Updated FitsLv0 header: eclplane_049_20250803111712.fits
# 2025-11-29 01:23:04,672 [INFO] Updated FitsLv0 header: eclplane_050_20250803112014.fits
# 2025-11-29 01:23:04,760 [INFO] Updated FitsLv0 header: eclplane_051_20250803112317.fits
# 2025-11-29 01:23:04,845 [INFO] Updated FitsLv0 header: eclplane_052_20250803112619.fits
# 2025-11-29 01:23:04,930 [INFO] Updated FitsLv0 header: eclplane_053_20250803112921.fits
# 2025-11-29 01:23:05,012 [INFO] Updated FitsLv0 header: eclplane_054_20250803113223.fits
# 2025-11-29 01:23:05,095 [INFO] Updated FitsLv0 header: eclplane_055_20250803113525.fits
# 2025-11-29 01:23:05,176 [INFO] Updated FitsLv0 header: eclplane_056_20250803113827.fits
# 2025-11-29 01:23:05,258 [INFO] Updated FitsLv0 header: eclplane_057_20250803114129.fits
# 2025-11-29 01:23:05,340 [INFO] Updated FitsLv0 header: eclplane_058_20250803114432.fits
# 2025-11-29 01:23:05,424 [INFO] Updated FitsLv0 header: eclplane_059_20250803114734.fits
# 2025-11-29 01:23:05,515 [INFO] Updated FitsLv0 header: eclplane_060_20250803115036.fits
# 2025-11-29 01:23:05,603 [INFO] Updated FitsLv0 header: test_001_20250803083431.fits
# 2025-11-29 01:23:05,686 [INFO] Updated FitsLv0 header: test_001_20250803083646.fits
# 2025-11-29 01:23:05,769 [INFO] Updated FitsLv0 header: test_001_20250803084527.fits
# 2025-11-29 01:23:05,864 [INFO] Updated FitsLv0 header: test_001_20250803084601.fits

# %%
allfits.refresh()  # Refresh the file collection to reflect updated headers
allfits.summary.to_pandas().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 59 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   file      82 non-null     object
#  1   simple    82 non-null     bool
#  2   bitpix    82 non-null     int64
#  3   naxis     82 non-null     int64
#  4   naxis1    82 non-null     int64
#  5   naxis2    82 non-null     int64
#  6   lt        82 non-null     object
#  7   utc       82 non-null     object
#  8   jd        82 non-null     float64
#  9   exptime   82 non-null     float64
#  10  xbinning  82 non-null     int64
#  11  ybinning  82 non-null     int64
#  12  ccdtemp   82 non-null     float64
#  13  ra        82 non-null     float64
#  14  dec       82 non-null     float64
#  15  alt       82 non-null     float64
#  16  az        82 non-null     float64
#  17  focus     82 non-null     int64
#  18  focallen  82 non-null     float64
#  19  aptdia    82 non-null     float64
#  20  pixsz     82 non-null     float64
#  21  imagetyp  82 non-null     object
#  22  object    82 non-null     object
#  23  observat  82 non-null     object
#  24  lon       82 non-null     float64
#  25  lat       82 non-null     float64
#  26  elav      82 non-null     object
#  27  observer  82 non-null     object
#  28  bunit     82 non-null     object
#  29  filter    82 non-null     object
#  30  date-obs  82 non-null     object
#  31  mjd-obs   82 non-null     float64
#  32  utc-sta   82 non-null     object
#  33  utc-end   82 non-null     object
#  34  obsdate   82 non-null     object
#  35  instrume  82 non-null     object
#  36  detector  82 non-null     object
#  37  egain     82 non-null     float64
#  38  rdnoise   82 non-null     float64
#  39  obscode   82 non-null     object
#  40  elev      82 non-null     float64
#  41  telescop  82 non-null     object
#  42  biascorr  82 non-null     bool
#  43  darkcorr  82 non-null     bool
#  44  flatcorr  82 non-null     bool
#  45  datlevel  82 non-null     int64
#  46  combined  82 non-null     bool
#  47  selong    82 non-null     float64
#  48  melong    82 non-null     float64
#  49  gxlat     82 non-null     float64
#  50  gxlon     82 non-null     float64
#  51  eclat     82 non-null     float64
#  52  eclon     82 non-null     float64
#  53  bscale    82 non-null     int64
#  54  bzero     82 non-null     int64
#  55  history   82 non-null     object
#  56  gain      64 non-null     object
#  57  lowgain   64 non-null     object
#  58  epadu     64 non-null     object
# dtypes: bool(5), float64(22), int64(10), object(22)
# memory usage: 35.1+ KB

# %% [markdown]
# ### Combine Master Calibration Frame

# %%
bias_frame = allfits.files_filtered(imagetyp="BIAS", include_path=True)
dark_frame = allfits.files_filtered(imagetyp="DARK", include_path=True)
# sci_frame = allfits.files_filtered(imagetyp="LIGHT", include_path=True)

print(f"Number of bias frames: {len(bias_frame)}")
print(f"Number of dark frames: {len(dark_frame)}")
# Out:
# Number of bias frames: 9
# Number of dark frames: 9

# %%
comb = solopy.CombMaster(log_file=fpath_log)

# %%
comb.comb_master_bias(bias_frame, MASTERDIR, outname="kl4040")
# Out:
# 2025-11-29 01:23:12,954 [INFO] Starting master bias combination...
# 2025-11-29 01:23:12,955 [INFO] Loading 9 frames...
# 2025-11-29 01:23:13,078 [INFO] Combining 9 bias CCDData objects...
# INFO:astropy:splitting each image into 11 chunks to limit memory usage to 500000000.0 bytes.
# INFO: splitting each image into 11 chunks to limit memory usage to 500000000.0 bytes. [ccdproc.combiner]
# 2025-11-29 01:23:24,772 [INFO] Master bias saved to kl4040.bias.comb.20250803.fits
# PosixPath('../solo-data/calibration_files/kl4040.bias.comb.20250803.fits')

# %%
comb.comb_master_dark(dark_frame, MASTERDIR, outname="kl4040")
# Out:
# 2025-11-29 01:23:24,786 [INFO] Starting master dark creation...
# 2025-11-29 01:23:24,786 [INFO] Loading 9 frames...
# 2025-11-29 01:23:24,911 [INFO] Searching for closest master bias to JD=2460891.0...
# 2025-11-29 01:23:24,957 [INFO] Using master bias: kl4040.bias.comb.20250803.fits
# 2025-11-29 01:23:25,212 [INFO] Combining 9 darks for exptime 180.0s...
# INFO:astropy:splitting each image into 11 chunks to limit memory usage to 500000000.0 bytes.
# INFO: splitting each image into 11 chunks to limit memory usage to 500000000.0 bytes. [ccdproc.combiner]
# 2025-11-29 01:23:37,345 [INFO] Master dark saved to kl4040.dark.180s.comb.20250803.fits
# [PosixPath('../solo-data/calibration_files/kl4040.dark.180s.comb.20250803.fits')]

# %% [markdown]
# ### FitsLv1 (WCS update, preprocessing, zeropoint calculation)

# %%
allsci = allfits.files_filtered(imagetyp="LIGHT", include_path=True)
print("Number of science frames:", len(allsci))
# Out:
# Number of science frames: 266

# %%
lv1 = solopy.FitsLv1(log_file=fpath_log)

# %%
for fpath_sci in allsci:
    fpath_wcs = lv1.update_wcs(fpath_sci,
                               outdir=LV1_subdir,
                               cache_directory=WORKDIR/"astrometry_cache", 
                               return_fpath=True
                               )
# Out:
# 2025-11-29 00:26:23,161 [INFO] WCS match: RA=331.93996, DEC=7.18443, scale=2.969
# 2025-11-29 00:26:23,467 [INFO] WCS updated: alt25az100_001_20250723055108.wcs.fits
# 2025-11-29 00:26:25,884 [INFO] WCS match: RA=331.93938, DEC=7.15865, scale=2.969
# 2025-11-29 00:26:25,910 [INFO] WCS updated: alt25az100_002_20250723055210.wcs.fits
# 2025-11-29 00:26:28,241 [INFO] WCS match: RA=331.93936, DEC=7.15865, scale=2.969
# 2025-11-29 00:26:28,268 [INFO] WCS updated: alt25az100_003_20250723055312.wcs.fits
# 2025-11-29 00:26:30,674 [INFO] WCS match: RA=331.93694, DEC=7.15710, scale=2.970
# 2025-11-29 00:26:30,700 [INFO] WCS updated: alt25az100_004_20250723055414.wcs.fits
# 2025-11-29 00:26:33,147 [INFO] WCS match: RA=331.93703, DEC=7.15700, scale=2.970
# 2025-11-29 00:26:33,173 [INFO] WCS updated: alt25az100_005_20250723055516.wcs.fits
# 2025-11-29 00:26:35,522 [INFO] WCS match: RA=312.15267, DEC=-22.10442, scale=2.967
# 2025-11-29 00:26:35,548 [INFO] WCS updated: alt25az150_001_20250723065438.wcs.fits
# 2025-11-29 00:26:37,833 [INFO] WCS match: RA=312.15143, DEC=-22.16955, scale=2.967
# 2025-11-29 00:26:37,859 [INFO] WCS updated: alt25az150_002_20250723065540.wcs.fits
# 2025-11-29 00:26:40,167 [INFO] WCS match: RA=312.15389, DEC=-22.16937, scale=2.971
# 2025-11-29 00:26:40,192 [INFO] WCS updated: alt25az150_003_20250723065642.wcs.fits
# 2025-11-29 00:26:42,516 [INFO] WCS match: RA=312.18615, DEC=-22.17060, scale=2.968
# 2025-11-29 00:26:42,542 [INFO] WCS updated: alt25az150_004_20250723065745.wcs.fits
# 2025-11-29 00:26:44,946 [INFO] WCS match: RA=312.34199, DEC=-22.17350, scale=2.970
# 2025-11-29 00:26:44,974 [INFO] WCS updated: alt25az150_005_20250723065847.wcs.fits
# 2025-11-29 00:26:47,349 [INFO] WCS match: RA=241.44403, DEC=0.45953, scale=2.968
# 2025-11-29 00:26:47,376 [INFO] WCS updated: alt25az250_001_20250723075817.wcs.fits
# 2025-11-29 00:26:49,728 [INFO] WCS match: RA=241.44397, DEC=0.45969, scale=2.968
# 2025-11-29 00:26:49,755 [INFO] WCS updated: alt25az250_002_20250723075919.wcs.fits
# 2025-11-29 00:26:52,090 [INFO] WCS match: RA=241.44400, DEC=0.45949, scale=2.968
# 2025-11-29 00:26:52,115 [INFO] WCS updated: alt25az250_003_20250723080020.wcs.fits
# 2025-11-29 00:26:54,455 [INFO] WCS match: RA=241.44393, DEC=0.45948, scale=2.968
# 2025-11-29 00:26:54,481 [INFO] WCS updated: alt25az250_004_20250723080122.wcs.fits
# 2025-11-29 00:26:56,804 [INFO] WCS match: RA=241.44399, DEC=0.45958, scale=2.968
# 2025-11-29 00:26:56,830 [INFO] WCS updated: alt25az250_005_20250723080224.wcs.fits
# 2025-11-29 00:26:58,951 [INFO] WCS match: RA=230.61773, DEC=38.17253, scale=2.967
# 2025-11-29 00:26:58,978 [INFO] WCS updated: alt25az300_001_20250723090153.wcs.fits
# 2025-11-29 00:27:01,093 [INFO] WCS match: RA=230.61780, DEC=38.17254, scale=2.967
# 2025-11-29 00:27:01,118 [INFO] WCS updated: alt25az300_002_20250723090255.wcs.fits
# 2025-11-29 00:27:03,208 [INFO] WCS match: RA=230.61780, DEC=38.17251, scale=2.967
# 2025-11-29 00:27:03,235 [INFO] WCS updated: alt25az300_003_20250723090357.wcs.fits
# 2025-11-29 00:27:05,338 [INFO] WCS match: RA=230.61779, DEC=38.17254, scale=2.968
# 2025-11-29 00:27:05,363 [INFO] WCS updated: alt25az300_004_20250723090459.wcs.fits
# 2025-11-29 00:27:07,446 [INFO] WCS match: RA=230.61785, DEC=38.17243, scale=2.968
# 2025-11-29 00:27:07,473 [INFO] WCS updated: alt25az300_005_20250723090601.wcs.fits
# 2025-11-29 00:27:11,504 [INFO] WCS match: RA=342.50336, DEC=45.84032, scale=2.971
# 2025-11-29 00:27:11,530 [INFO] WCS updated: alt25az50_001_20250723044527.wcs.fits
# 2025-11-29 00:27:15,828 [INFO] WCS match: RA=343.04618, DEC=45.80983, scale=2.972
# 2025-11-29 00:27:15,855 [INFO] WCS updated: alt25az50_001_20250723044735.wcs.fits
# 2025-11-29 00:27:20,407 [INFO] WCS match: RA=342.93546, DEC=45.81112, scale=2.972
# 2025-11-29 00:27:20,433 [INFO] WCS updated: alt25az50_002_20250723044837.wcs.fits
# 2025-11-29 00:27:24,894 [INFO] WCS match: RA=343.04593, DEC=45.80976, scale=2.971
# 2025-11-29 00:27:24,920 [INFO] WCS updated: alt25az50_003_20250723044939.wcs.fits
# 2025-11-29 00:27:29,400 [INFO] WCS match: RA=343.04617, DEC=45.80965, scale=2.971
# 2025-11-29 00:27:29,426 [INFO] WCS updated: alt25az50_004_20250723045041.wcs.fits
# 2025-11-29 00:27:33,945 [INFO] WCS match: RA=343.04620, DEC=45.80982, scale=2.971
# 2025-11-29 00:27:33,972 [INFO] WCS updated: alt25az50_005_20250723045143.wcs.fits
# 2025-11-29 00:27:36,605 [INFO] WCS match: RA=315.54735, DEC=-13.54576, scale=2.967
# 2025-11-29 00:27:36,631 [INFO] WCS updated: alt30az140_001_20250723064305.wcs.fits
# 2025-11-29 00:27:39,267 [INFO] WCS match: RA=315.54891, DEC=-13.54585, scale=2.966
# 2025-11-29 00:27:39,294 [INFO] WCS updated: alt30az140_002_20250723064407.wcs.fits
# 2025-11-29 00:27:41,937 [INFO] WCS match: RA=315.54889, DEC=-13.54587, scale=2.966
# 2025-11-29 00:27:41,962 [INFO] WCS updated: alt30az140_003_20250723064509.wcs.fits
# 2025-11-29 00:27:44,642 [INFO] WCS match: RA=315.54888, DEC=-13.54586, scale=2.966
# 2025-11-29 00:27:44,668 [INFO] WCS updated: alt30az140_004_20250723064611.wcs.fits
# 2025-11-29 00:27:47,357 [INFO] WCS match: RA=315.54890, DEC=-13.54585, scale=2.966
# 2025-11-29 00:27:47,383 [INFO] WCS updated: alt30az140_005_20250723064713.wcs.fits
# 2025-11-29 00:27:50,007 [INFO] WCS match: RA=248.29640, DEC=-2.46017, scale=2.966
# 2025-11-29 00:27:50,035 [INFO] WCS updated: alt30az240_001_20250723074643.wcs.fits
# 2025-11-29 00:27:52,616 [INFO] WCS match: RA=248.29647, DEC=-2.46012, scale=2.966
# 2025-11-29 00:27:52,643 [INFO] WCS updated: alt30az240_002_20250723074745.wcs.fits
# 2025-11-29 00:27:55,232 [INFO] WCS match: RA=248.29648, DEC=-2.46006, scale=2.966
# 2025-11-29 00:27:55,259 [INFO] WCS updated: alt30az240_003_20250723074847.wcs.fits
# 2025-11-29 00:27:57,836 [INFO] WCS match: RA=248.29651, DEC=-2.46004, scale=2.966
# 2025-11-29 00:27:57,862 [INFO] WCS updated: alt30az240_004_20250723074949.wcs.fits
# 2025-11-29 00:28:00,405 [INFO] WCS match: RA=248.29647, DEC=-2.46005, scale=2.966
# 2025-11-29 00:28:00,432 [INFO] WCS updated: alt30az240_005_20250723075051.wcs.fits
# 2025-11-29 00:28:02,748 [INFO] WCS match: RA=238.24778, DEC=32.59091, scale=2.967
# 2025-11-29 00:28:02,774 [INFO] WCS updated: alt30az290_001_20250723085019.wcs.fits
# 2025-11-29 00:28:05,010 [INFO] WCS match: RA=238.24776, DEC=32.59078, scale=2.967
# 2025-11-29 00:28:05,038 [INFO] WCS updated: alt30az290_002_20250723085121.wcs.fits
# 2025-11-29 00:28:07,290 [INFO] WCS match: RA=238.24769, DEC=32.59083, scale=2.966
# 2025-11-29 00:28:07,319 [INFO] WCS updated: alt30az290_003_20250723085223.wcs.fits
# 2025-11-29 00:28:09,589 [INFO] WCS match: RA=238.24773, DEC=32.59080, scale=2.967
# 2025-11-29 00:28:09,616 [INFO] WCS updated: alt30az290_004_20250723085325.wcs.fits
# 2025-11-29 00:28:11,899 [INFO] WCS match: RA=238.20671, DEC=32.59205, scale=2.965
# 2025-11-29 00:28:11,925 [INFO] WCS updated: alt30az290_005_20250723085427.wcs.fits
# 2025-11-29 00:28:14,529 [INFO] WCS match: RA=330.18429, DEC=17.27797, scale=2.969
# 2025-11-29 00:28:14,559 [INFO] WCS updated: alt30az90_001_20250723053935.wcs.fits
# 2025-11-29 00:28:17,194 [INFO] WCS match: RA=330.18404, DEC=17.27747, scale=2.968
# 2025-11-29 00:28:17,220 [INFO] WCS updated: alt30az90_002_20250723054037.wcs.fits
# 2025-11-29 00:28:19,948 [INFO] WCS match: RA=330.18435, DEC=17.27784, scale=2.968
# 2025-11-29 00:28:19,976 [INFO] WCS updated: alt30az90_003_20250723054139.wcs.fits
# 2025-11-29 00:28:22,849 [INFO] WCS match: RA=330.18437, DEC=17.27791, scale=2.968
# 2025-11-29 00:28:22,875 [INFO] WCS updated: alt30az90_004_20250723054241.wcs.fits
# 2025-11-29 00:28:25,748 [INFO] WCS match: RA=330.18431, DEC=17.27800, scale=2.968
# 2025-11-29 00:28:25,774 [INFO] WCS updated: alt30az90_005_20250723054343.wcs.fits
# 2025-11-29 00:28:28,434 [INFO] WCS match: RA=316.79353, DEC=-4.52136, scale=2.970
# 2025-11-29 00:28:28,461 [INFO] WCS updated: alt35az130_001_20250723063132.wcs.fits
# 2025-11-29 00:28:31,268 [INFO] WCS match: RA=316.79255, DEC=-4.58570, scale=2.968
# 2025-11-29 00:28:31,296 [INFO] WCS updated: alt35az130_002_20250723063234.wcs.fits
# 2025-11-29 00:28:34,072 [INFO] WCS match: RA=316.79229, DEC=-4.58633, scale=2.970
# 2025-11-29 00:28:34,098 [INFO] WCS updated: alt35az130_003_20250723063336.wcs.fits
# 2025-11-29 00:28:36,865 [INFO] WCS match: RA=316.79228, DEC=-4.58638, scale=2.970
# 2025-11-29 00:28:36,890 [INFO] WCS updated: alt35az130_004_20250723063438.wcs.fits
# 2025-11-29 00:28:39,733 [INFO] WCS match: RA=316.79228, DEC=-4.58639, scale=2.970
# 2025-11-29 00:28:39,760 [INFO] WCS updated: alt35az130_005_20250723063540.wcs.fits
# 2025-11-29 00:28:42,777 [INFO] WCS match: RA=254.88049, DEC=-4.27005, scale=2.964
# 2025-11-29 00:28:42,803 [INFO] WCS updated: alt35az230_001_20250723073509.wcs.fits
# 2025-11-29 00:28:45,738 [INFO] WCS match: RA=254.88051, DEC=-4.27005, scale=2.965
# 2025-11-29 00:28:45,766 [INFO] WCS updated: alt35az230_002_20250723073611.wcs.fits
# 2025-11-29 00:28:48,704 [INFO] WCS match: RA=254.88052, DEC=-4.27003, scale=2.964
# 2025-11-29 00:28:48,730 [INFO] WCS updated: alt35az230_003_20250723073713.wcs.fits
# 2025-11-29 00:28:51,636 [INFO] WCS match: RA=254.88054, DEC=-4.27001, scale=2.964
# 2025-11-29 00:28:51,663 [INFO] WCS updated: alt35az230_004_20250723073815.wcs.fits
# 2025-11-29 00:28:54,534 [INFO] WCS match: RA=254.88055, DEC=-4.27003, scale=2.965
# 2025-11-29 00:28:54,561 [INFO] WCS updated: alt35az230_005_20250723073917.wcs.fits
# 2025-11-29 00:28:56,922 [INFO] WCS match: RA=244.80200, DEC=27.39059, scale=2.964
# 2025-11-29 00:28:56,948 [INFO] WCS updated: alt35az280_001_20250723083844.wcs.fits
# 2025-11-29 00:28:59,242 [INFO] WCS match: RA=244.80209, DEC=27.39069, scale=2.964
# 2025-11-29 00:28:59,268 [INFO] WCS updated: alt35az280_002_20250723083947.wcs.fits
# 2025-11-29 00:29:01,574 [INFO] WCS match: RA=244.80200, DEC=27.39066, scale=2.964
# 2025-11-29 00:29:01,601 [INFO] WCS updated: alt35az280_003_20250723084049.wcs.fits
# 2025-11-29 00:29:03,898 [INFO] WCS match: RA=244.80308, DEC=27.42338, scale=2.964
# 2025-11-29 00:29:03,925 [INFO] WCS updated: alt35az280_004_20250723084151.wcs.fits
# 2025-11-29 00:29:06,239 [INFO] WCS match: RA=244.80314, DEC=27.42339, scale=2.964
# 2025-11-29 00:29:06,265 [INFO] WCS updated: alt35az280_005_20250723084253.wcs.fits
# 2025-11-29 00:29:09,811 [INFO] WCS match: RA=327.34304, DEC=27.10599, scale=2.968
# 2025-11-29 00:29:09,837 [INFO] WCS updated: alt35az80_001_20250723052801.wcs.fits
# 2025-11-29 00:29:13,594 [INFO] WCS match: RA=327.34270, DEC=27.08652, scale=2.968
# 2025-11-29 00:29:13,623 [INFO] WCS updated: alt35az80_002_20250723052903.wcs.fits
# 2025-11-29 00:29:17,338 [INFO] WCS match: RA=327.34267, DEC=27.08656, scale=2.968
# 2025-11-29 00:29:17,364 [INFO] WCS updated: alt35az80_003_20250723053006.wcs.fits
# 2025-11-29 00:29:21,141 [INFO] WCS match: RA=327.34270, DEC=27.08655, scale=2.968
# 2025-11-29 00:29:21,167 [INFO] WCS updated: alt35az80_004_20250723053108.wcs.fits
# 2025-11-29 00:29:25,062 [INFO] WCS match: RA=327.34270, DEC=27.08651, scale=2.968
# 2025-11-29 00:29:25,088 [INFO] WCS updated: alt35az80_005_20250723053210.wcs.fits
# 2025-11-29 00:29:28,165 [INFO] WCS match: RA=316.72085, DEC=4.38209, scale=2.965
# 2025-11-29 00:29:28,190 [INFO] WCS updated: alt40az120_001_20250723061959.wcs.fits
# 2025-11-29 00:29:31,322 [INFO] WCS match: RA=316.78341, DEC=4.38092, scale=2.965
# 2025-11-29 00:29:31,348 [INFO] WCS updated: alt40az120_002_20250723062101.wcs.fits
# 2025-11-29 00:29:34,480 [INFO] WCS match: RA=316.78419, DEC=4.38122, scale=2.963
# 2025-11-29 00:29:34,506 [INFO] WCS updated: alt40az120_003_20250723062203.wcs.fits
# 2025-11-29 00:29:37,630 [INFO] WCS match: RA=316.78341, DEC=4.38096, scale=2.965
# 2025-11-29 00:29:37,656 [INFO] WCS updated: alt40az120_004_20250723062305.wcs.fits
# 2025-11-29 00:29:40,816 [INFO] WCS match: RA=316.78347, DEC=4.38098, scale=2.965
# 2025-11-29 00:29:40,842 [INFO] WCS updated: alt40az120_005_20250723062407.wcs.fits
# 2025-11-29 00:29:43,801 [INFO] WCS match: RA=261.59079, DEC=-4.67537, scale=2.965
# 2025-11-29 00:29:43,827 [INFO] WCS updated: alt40az220_001_20250723072334.wcs.fits
# 2025-11-29 00:29:46,779 [INFO] WCS match: RA=261.59079, DEC=-4.67539, scale=2.965
# 2025-11-29 00:29:46,805 [INFO] WCS updated: alt40az220_002_20250723072437.wcs.fits
# 2025-11-29 00:29:49,746 [INFO] WCS match: RA=261.58051, DEC=-4.67522, scale=2.965
# 2025-11-29 00:29:49,772 [INFO] WCS updated: alt40az220_003_20250723072539.wcs.fits
# 2025-11-29 00:29:52,760 [INFO] WCS match: RA=261.59072, DEC=-4.67547, scale=2.965
# 2025-11-29 00:29:52,786 [INFO] WCS updated: alt40az220_004_20250723072641.wcs.fits
# 2025-11-29 00:29:55,774 [INFO] WCS match: RA=261.59075, DEC=-4.67534, scale=2.965
# 2025-11-29 00:29:55,800 [INFO] WCS updated: alt40az220_005_20250723072743.wcs.fits
# 2025-11-29 00:29:58,337 [INFO] WCS match: RA=251.03192, DEC=22.78891, scale=2.967
# 2025-11-29 00:29:58,364 [INFO] WCS updated: alt40az270_001_20250723082711.wcs.fits
# 2025-11-29 00:30:00,889 [INFO] WCS match: RA=251.03196, DEC=22.78897, scale=2.967
# 2025-11-29 00:30:00,915 [INFO] WCS updated: alt40az270_002_20250723082813.wcs.fits
# 2025-11-29 00:30:03,437 [INFO] WCS match: RA=251.03195, DEC=22.78895, scale=2.967
# 2025-11-29 00:30:03,463 [INFO] WCS updated: alt40az270_003_20250723082915.wcs.fits
# 2025-11-29 00:30:05,976 [INFO] WCS match: RA=251.03190, DEC=22.78894, scale=2.967
# 2025-11-29 00:30:06,002 [INFO] WCS updated: alt40az270_004_20250723083017.wcs.fits
# 2025-11-29 00:30:08,508 [INFO] WCS match: RA=251.03195, DEC=22.78895, scale=2.967
# 2025-11-29 00:30:08,534 [INFO] WCS updated: alt40az270_005_20250723083119.wcs.fits
# 2025-11-29 00:30:13,976 [INFO] WCS match: RA=322.77647, DEC=36.37747, scale=2.967
# 2025-11-29 00:30:14,002 [INFO] WCS updated: alt40az70_001_20250723051629.wcs.fits
# 2025-11-29 00:30:20,617 [INFO] WCS match: RA=322.77640, DEC=36.37750, scale=2.967
# 2025-11-29 00:30:20,643 [INFO] WCS updated: alt40az70_002_20250723051731.wcs.fits
# 2025-11-29 00:30:27,391 [INFO] WCS match: RA=322.77611, DEC=36.36326, scale=2.967
# 2025-11-29 00:30:27,417 [INFO] WCS updated: alt40az70_003_20250723051833.wcs.fits
# 2025-11-29 00:30:34,402 [INFO] WCS match: RA=322.77616, DEC=36.36322, scale=2.967
# 2025-11-29 00:30:34,429 [INFO] WCS updated: alt40az70_004_20250723051935.wcs.fits
# 2025-11-29 00:30:41,501 [INFO] WCS match: RA=322.77622, DEC=36.36327, scale=2.967
# 2025-11-29 00:30:41,527 [INFO] WCS updated: alt40az70_005_20250723052037.wcs.fits
# 2025-11-29 00:30:45,228 [INFO] WCS match: RA=315.25850, DEC=13.29355, scale=2.965
# 2025-11-29 00:30:45,254 [INFO] WCS updated: alt45az110_001_20250723060827.wcs.fits
# 2025-11-29 00:30:49,275 [INFO] WCS match: RA=315.25848, DEC=13.29338, scale=2.965
# 2025-11-29 00:30:49,302 [INFO] WCS updated: alt45az110_002_20250723060929.wcs.fits
# 2025-11-29 00:30:53,361 [INFO] WCS match: RA=315.25809, DEC=13.29338, scale=2.968
# 2025-11-29 00:30:53,387 [INFO] WCS updated: alt45az110_003_20250723061031.wcs.fits
# 2025-11-29 00:30:57,455 [INFO] WCS match: RA=315.25822, DEC=13.29337, scale=2.968
# 2025-11-29 00:30:57,481 [INFO] WCS updated: alt45az110_004_20250723061133.wcs.fits
# 2025-11-29 00:31:01,536 [INFO] WCS match: RA=315.25735, DEC=13.23141, scale=2.965
# 2025-11-29 00:31:01,563 [INFO] WCS updated: alt45az110_005_20250723061235.wcs.fits
# 2025-11-29 00:31:04,789 [INFO] WCS match: RA=267.47112, DEC=-3.66498, scale=2.967
# 2025-11-29 00:31:04,815 [INFO] WCS updated: alt45az210_001_20250723071159.wcs.fits
# 2025-11-29 00:31:08,524 [INFO] WCS match: RA=267.46948, DEC=-3.73058, scale=2.966
# 2025-11-29 00:31:08,549 [INFO] WCS updated: alt45az210_002_20250723071301.wcs.fits
# 2025-11-29 00:31:12,477 [INFO] WCS match: RA=267.46935, DEC=-3.73064, scale=2.966
# 2025-11-29 00:31:12,503 [INFO] WCS updated: alt45az210_003_20250723071404.wcs.fits
# 2025-11-29 00:31:16,482 [INFO] WCS match: RA=267.46946, DEC=-3.73058, scale=2.966
# 2025-11-29 00:31:16,509 [INFO] WCS updated: alt45az210_004_20250723071506.wcs.fits
# 2025-11-29 00:31:20,527 [INFO] WCS match: RA=267.46917, DEC=-3.74491, scale=2.967
# 2025-11-29 00:31:20,553 [INFO] WCS updated: alt45az210_005_20250723071608.wcs.fits
# 2025-11-29 00:31:23,306 [INFO] WCS match: RA=256.79494, DEC=19.17821, scale=2.968
# 2025-11-29 00:31:23,332 [INFO] WCS updated: alt45az260_001_20250723081536.wcs.fits
# 2025-11-29 00:31:26,069 [INFO] WCS match: RA=256.79483, DEC=19.17828, scale=2.968
# 2025-11-29 00:31:26,095 [INFO] WCS updated: alt45az260_002_20250723081639.wcs.fits
# 2025-11-29 00:31:28,822 [INFO] WCS match: RA=256.79483, DEC=19.17826, scale=2.968
# 2025-11-29 00:31:28,848 [INFO] WCS updated: alt45az260_003_20250723081741.wcs.fits
# 2025-11-29 00:31:31,577 [INFO] WCS match: RA=256.79489, DEC=19.17819, scale=2.968
# 2025-11-29 00:31:31,603 [INFO] WCS updated: alt45az260_004_20250723081843.wcs.fits
# 2025-11-29 00:31:34,345 [INFO] WCS match: RA=256.79485, DEC=19.17819, scale=2.967
# 2025-11-29 00:31:34,371 [INFO] WCS updated: alt45az260_005_20250723081945.wcs.fits
# 2025-11-29 00:31:41,542 [INFO] WCS match: RA=316.37422, DEC=45.06716, scale=2.968
# 2025-11-29 00:31:41,568 [INFO] WCS updated: alt45az60_001_20250723050456.wcs.fits
# 2025-11-29 00:31:52,645 [INFO] WCS match: RA=316.42546, DEC=45.06657, scale=2.967
# 2025-11-29 00:31:52,671 [INFO] WCS updated: alt45az60_002_20250723050558.wcs.fits
# 2025-11-29 00:32:03,502 [INFO] WCS match: RA=316.42576, DEC=45.06658, scale=2.967
# 2025-11-29 00:32:03,527 [INFO] WCS updated: alt45az60_003_20250723050700.wcs.fits
# 2025-11-29 00:32:14,941 [INFO] WCS match: RA=316.42574, DEC=45.06650, scale=2.967
# 2025-11-29 00:32:14,968 [INFO] WCS updated: alt45az60_004_20250723050802.wcs.fits
# 2025-11-29 00:32:26,812 [INFO] WCS match: RA=316.42584, DEC=45.06657, scale=2.967
# 2025-11-29 00:32:26,838 [INFO] WCS updated: alt45az60_005_20250723050904.wcs.fits
# 2025-11-29 00:32:33,827 [INFO] WCS match: RA=312.24170, DEC=21.54365, scale=2.967
# 2025-11-29 00:32:33,853 [INFO] WCS updated: alt50az100_001_20250723055654.wcs.fits
# 2025-11-29 00:32:40,808 [INFO] WCS match: RA=312.25502, DEC=21.54329, scale=2.967
# 2025-11-29 00:32:40,834 [INFO] WCS updated: alt50az100_002_20250723055756.wcs.fits
# 2025-11-29 00:32:47,859 [INFO] WCS match: RA=312.24250, DEC=21.60649, scale=2.967
# 2025-11-29 00:32:47,886 [INFO] WCS updated: alt50az100_003_20250723055858.wcs.fits
# 2025-11-29 00:32:55,288 [INFO] WCS match: RA=312.24326, DEC=21.60672, scale=2.967
# 2025-11-29 00:32:55,314 [INFO] WCS updated: alt50az100_004_20250723060000.wcs.fits
# 2025-11-29 00:33:02,603 [INFO] WCS match: RA=312.24192, DEC=21.54343, scale=2.967
# 2025-11-29 00:33:02,629 [INFO] WCS updated: alt50az100_005_20250723060102.wcs.fits
# 2025-11-29 00:33:07,694 [INFO] WCS match: RA=303.87023, DEC=0.70676, scale=2.965
# 2025-11-29 00:33:07,722 [INFO] WCS updated: alt50az150_001_20250723070025.wcs.fits
# 2025-11-29 00:33:12,819 [INFO] WCS match: RA=303.87027, DEC=0.70669, scale=2.965
# 2025-11-29 00:33:12,845 [INFO] WCS updated: alt50az150_002_20250723070127.wcs.fits
# 2025-11-29 00:33:17,888 [INFO] WCS match: RA=303.87028, DEC=0.70674, scale=2.965
# 2025-11-29 00:33:17,914 [INFO] WCS updated: alt50az150_003_20250723070229.wcs.fits
# 2025-11-29 00:33:22,923 [INFO] WCS match: RA=303.87031, DEC=0.70676, scale=2.965
# 2025-11-29 00:33:22,949 [INFO] WCS updated: alt50az150_004_20250723070331.wcs.fits
# 2025-11-29 00:33:28,047 [INFO] WCS match: RA=303.87029, DEC=0.70673, scale=2.965
# 2025-11-29 00:33:28,073 [INFO] WCS updated: alt50az150_005_20250723070433.wcs.fits
# 2025-11-29 00:33:31,325 [INFO] WCS match: RA=262.20468, DEC=16.65540, scale=2.964
# 2025-11-29 00:33:31,351 [INFO] WCS updated: alt50az250_001_20250723080403.wcs.fits
# 2025-11-29 00:33:34,718 [INFO] WCS match: RA=262.20477, DEC=16.65527, scale=2.964
# 2025-11-29 00:33:34,745 [INFO] WCS updated: alt50az250_002_20250723080505.wcs.fits
# 2025-11-29 00:33:38,127 [INFO] WCS match: RA=262.20475, DEC=16.65534, scale=2.964
# 2025-11-29 00:33:38,153 [INFO] WCS updated: alt50az250_003_20250723080607.wcs.fits
# 2025-11-29 00:33:41,214 [INFO] WCS match: RA=262.20478, DEC=16.65536, scale=2.964
# 2025-11-29 00:33:41,239 [INFO] WCS updated: alt50az250_004_20250723080709.wcs.fits
# 2025-11-29 00:33:43,794 [INFO] WCS match: RA=262.20191, DEC=16.65553, scale=2.965
# 2025-11-29 00:33:43,820 [INFO] WCS updated: alt50az250_005_20250723080811.wcs.fits
# 2025-11-29 00:33:46,447 [INFO] WCS match: RA=264.36568, DEC=45.83655, scale=2.966
# 2025-11-29 00:33:46,473 [INFO] WCS updated: alt50az300_001_20250723090740.wcs.fits
# 2025-11-29 00:33:49,109 [INFO] WCS match: RA=264.36568, DEC=45.83655, scale=2.966
# 2025-11-29 00:33:49,135 [INFO] WCS updated: alt50az300_002_20250723090842.wcs.fits
# 2025-11-29 00:33:51,783 [INFO] WCS match: RA=264.36573, DEC=45.83655, scale=2.966
# 2025-11-29 00:33:51,810 [INFO] WCS updated: alt50az300_003_20250723090944.wcs.fits
# 2025-11-29 00:33:54,452 [INFO] WCS match: RA=264.36572, DEC=45.83658, scale=2.966
# 2025-11-29 00:33:54,480 [INFO] WCS updated: alt50az300_004_20250723091046.wcs.fits
# 2025-11-29 00:33:57,124 [INFO] WCS match: RA=264.36576, DEC=45.83653, scale=2.966
# 2025-11-29 00:33:57,150 [INFO] WCS updated: alt50az300_005_20250723091148.wcs.fits
# 2025-11-29 00:34:04,540 [INFO] WCS match: RA=306.99730, DEC=52.12540, scale=2.965
# 2025-11-29 00:34:04,566 [INFO] WCS updated: alt50az50_001_20250723045322.wcs.fits
# 2025-11-29 00:34:12,664 [INFO] WCS match: RA=306.99728, DEC=52.12540, scale=2.965
# 2025-11-29 00:34:12,690 [INFO] WCS updated: alt50az50_002_20250723045425.wcs.fits
# 2025-11-29 00:34:21,082 [INFO] WCS match: RA=306.99740, DEC=52.12519, scale=2.965
# 2025-11-29 00:34:21,109 [INFO] WCS updated: alt50az50_003_20250723045527.wcs.fits
# 2025-11-29 00:34:29,385 [INFO] WCS match: RA=306.99738, DEC=52.12515, scale=2.965
# 2025-11-29 00:34:29,412 [INFO] WCS updated: alt50az50_004_20250723045629.wcs.fits
# 2025-11-29 00:34:38,000 [INFO] WCS match: RA=306.99727, DEC=52.12536, scale=2.965
# 2025-11-29 00:34:38,027 [INFO] WCS updated: alt50az50_005_20250723045731.wcs.fits
# 2025-11-29 00:42:29,900 [INFO] WCS match: RA=304.14670, DEC=7.99185, scale=2.965
# 2025-11-29 00:42:29,950 [INFO] WCS updated: alt55az140_001_20250723064852.wcs.fits
# 2025-11-29 00:42:36,198 [INFO] WCS match: RA=304.14363, DEC=7.99191, scale=2.965
# 2025-11-29 00:42:36,223 [INFO] WCS updated: alt55az140_002_20250723064954.wcs.fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 for fpath_sci in allsci:
# ----> 2     fpath_wcs = lv1.update_wcs(fpath_sci,
#       3                                outdir=LV1_subdir,
#       4                                cache_directory=WORKDIR/"astrometry_cache",
#       5                                return_fpath=True
#       6                                )
#
# File ~/Desktop/solopy/solopy/fitslv1.py:63, in FitsLv1.update_wcs(self, fpath_fits, outdir, cache_directory, return_fpath)
#      61 try:
#      62     bkg = sep.Background(sci.data)
# ---> 63     objs = sep.extract(sci.data - bkg.back(), thresh=3.0 * bkg.globalrms, minarea=5)
#      64     bright = objs[np.argsort(objs['flux'])[::-1][:50]]
#      65     coords = np.vstack((bright['x'], bright['y'])).T
#
# KeyboardInterrupt:

# %%
logger.info("--- Step 3:  WCS solution update ---")
lv1 = solopy.Lv1(log_file=fpath_log_lv1)

# Collect all Lv0 fits files
all_lv0_fits = ccdproc.ImageFileCollection(LV0_subdir, glob_exclude="*.bz2", glob_include="*.fits")
science_frames = all_lv0_fits.files_filtered(IMAGETYP="LIGHT", include_path=True)

TMPDIR = WORKDIR/"tmp"
TMPDIR.mkdir(parents=True, exist_ok=True)

if science_frames:
    for fpath_sci in science_frames:
        fpath_wcs = lv1.update_wcs(fpath_sci, TMPDIR, cache_directory=WORKDIR/"astrometry_cache", return_fpath=True)
        print(fpath_wcs)
# Out:
# 2025-11-03 16:58:12,353 [INFO] --- Step 3:  WCS solution update ---
# 2025-11-03 16:58:16,896 [WARNING] Astrometry.net solver failed for longexp_001_20250719065814.fits: Solver.__init__() got an unexpected keyword argument 'log_level'
# 2025-11-03 16:58:16,896 [WARNING] Skipping center coord calculation for longexp_001_20250719065814.fits (no WCS).
# 2025-11-03 16:58:16,922 [INFO] WCS updated: longexp_001_20250719065814.wcs.fits
# ../solo-data/tmp/longexp_001_20250719065814.wcs.fits
# 2025-11-03 16:58:21,037 [WARNING] Astrometry.net solver failed for longexp_001_20250719070221.fits: Solver.__init__() got an unexpected keyword argument 'log_level'
# 2025-11-03 16:58:21,037 [WARNING] Skipping center coord calculation for longexp_001_20250719070221.fits (no WCS).
# 2025-11-03 16:58:21,055 [INFO] WCS updated: longexp_001_20250719070221.wcs.fits
# ../solo-data/tmp/longexp_001_20250719070221.wcs.fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#      11 if science_frames:
#      12     for fpath_sci in science_frames:
# ---> 13         fpath_wcs = lv1.update_wcs(fpath_sci, TMPDIR, cache_directory=DATADIR/"astrometry_cache", return_fpath=True)
#      14         print(fpath_wcs)
#
# File ~/Desktop/solopy/solopy/Lv1.py:61, in Lv1.update_wcs(self, fpath_fits, outdir, cache_directory, return_fpath)
#      59 try:
#      60     bkg = sep.Background(sci.data)
# ---> 61     objs = sep.extract(sci.data - bkg.back(), thresh=3.0 * bkg.globalrms, minarea=5)
#      62     bright = objs[np.argsort(objs['flux'])[::-1][:50]]
#      63     coords = np.vstack((bright['x'], bright['y'])).T
#
# KeyboardInterrupt:

# %%
# Out:
# 2025-11-03 16:35:58,063 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:36:01,762 [INFO] downloading 3 files (169.19 MB)
# 2025-11-03 16:36:02,916 [INFO] downloading "http://data.astrometry.net/4100/index-4108.fits" to "/Users/bumhoo7/Desktop/solopy/notebook/astrometry_cache/4100/index-4108.fits"
# 2025-11-03 16:36:02,916 [INFO] downloading "http://data.astrometry.net/4100/index-4109.fits" to "/Users/bumhoo7/Desktop/solopy/notebook/astrometry_cache/4100/index-4109.fits"
# 2025-11-03 16:36:02,917 [INFO] downloading "http://data.astrometry.net/4100/index-4110.fits" to "/Users/bumhoo7/Desktop/solopy/notebook/astrometry_cache/4100/index-4110.fits"
# 2025-11-03 16:38:07,044 [INFO] loaded 3 index files
# 2025-11-03 16:38:07,046 [INFO] solve 1: start
# 2025-11-03 16:38:07,048 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:07,213 [INFO] solve 1: logodds=239.887, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9716, scale=2.96297, index="4100/index-4108.fits"
# 2025-11-03 16:38:07,366 [INFO] solve 1: logodds=222.926, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9684, scale=2.96331, index="4100/index-4108.fits"
# 2025-11-03 16:38:07,521 [INFO] solve 1: logodds=222.704, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9693, scale=2.9635, index="4100/index-4108.fits"
# 2025-11-03 16:38:07,522 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:07,675 [INFO] solve 1: logodds=285.816, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9708, scale=2.9624, index="4100/index-4109.fits"
# 2025-11-03 16:38:07,826 [INFO] solve 1: logodds=285.675, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9707, scale=2.96256, index="4100/index-4109.fits"
# 2025-11-03 16:38:07,975 [INFO] solve 1: logodds=284.585, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.971, scale=2.96296, index="4100/index-4109.fits"
# 2025-11-03 16:38:08,123 [INFO] solve 1: logodds=258.182, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9693, scale=2.96378, index="4100/index-4109.fits"
# 2025-11-03 16:38:08,288 [INFO] solve 1: logodds=266.998, matches=41, conflicts=0, distractors=5, ra=270.192, dec=29.9709, scale=2.96483, index="4100/index-4109.fits"
# 2025-11-03 16:38:08,440 [INFO] solve 1: logodds=268.891, matches=41, conflicts=0, distractors=5, ra=270.192, dec=29.9698, scale=2.96321, index="4100/index-4109.fits"
# 2025-11-03 16:38:08,589 [INFO] solve 1: logodds=271.008, matches=41, conflicts=0, distractors=5, ra=270.193, dec=29.9695, scale=2.96425, index="4100/index-4109.fits"
# 2025-11-03 16:38:08,787 [INFO] WCS match: RA=270.19466, DEC=29.97082, scale=2.962
# 2025-11-03 16:38:08,787 [INFO] WCS match: RA=270.19466, DEC=29.97082, scale=2.962
# 2025-11-03 16:38:09,071 [INFO] WCS updated: longexp_001_20250719065814.wcs.fits
# 2025-11-03 16:38:09,071 [INFO] WCS updated: longexp_001_20250719065814.wcs.fits
# 2025-11-03 16:38:09,150 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/longexp_001_20250719065814.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:13,381 [INFO] loaded 3 index files
# 2025-11-03 16:38:13,381 [INFO] solve 1: start
# 2025-11-03 16:38:13,383 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:13,555 [INFO] solve 1: logodds=238.681, matches=42, conflicts=0, distractors=4, ra=270.197, dec=29.972, scale=2.96288, index="4100/index-4108.fits"
# 2025-11-03 16:38:13,709 [INFO] solve 1: logodds=223.576, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9683, scale=2.96347, index="4100/index-4108.fits"
# 2025-11-03 16:38:13,865 [INFO] solve 1: logodds=223.276, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9691, scale=2.96366, index="4100/index-4108.fits"
# 2025-11-03 16:38:13,867 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:14,015 [INFO] solve 1: logodds=285.478, matches=41, conflicts=0, distractors=5, ra=270.194, dec=29.9708, scale=2.96246, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,166 [INFO] solve 1: logodds=285.483, matches=41, conflicts=0, distractors=5, ra=270.194, dec=29.9708, scale=2.96258, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,315 [INFO] solve 1: logodds=284.651, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.971, scale=2.96303, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,465 [INFO] solve 1: logodds=259.296, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9691, scale=2.96401, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,615 [INFO] solve 1: logodds=268.818, matches=41, conflicts=0, distractors=5, ra=270.192, dec=29.9709, scale=2.9651, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,764 [INFO] solve 1: logodds=268.879, matches=41, conflicts=0, distractors=5, ra=270.191, dec=29.9693, scale=2.96337, index="4100/index-4109.fits"
# 2025-11-03 16:38:14,915 [INFO] solve 1: logodds=272.899, matches=41, conflicts=0, distractors=5, ra=270.193, dec=29.9695, scale=2.96451, index="4100/index-4109.fits"
# 2025-11-03 16:38:15,116 [INFO] WCS match: RA=270.19441, DEC=29.97075, scale=2.963
# 2025-11-03 16:38:15,116 [INFO] WCS match: RA=270.19441, DEC=29.97075, scale=2.963
# 2025-11-03 16:38:15,142 [INFO] WCS updated: longexp_001_20250719070221.wcs.fits
# 2025-11-03 16:38:15,142 [INFO] WCS updated: longexp_001_20250719070221.wcs.fits
# 2025-11-03 16:38:15,209 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/longexp_001_20250719070221.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:19,529 [INFO] loaded 3 index files
# 2025-11-03 16:38:19,530 [INFO] solve 1: start
# 2025-11-03 16:38:19,531 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:19,693 [INFO] solve 1: logodds=240.196, matches=42, conflicts=0, distractors=4, ra=270.197, dec=29.9719, scale=2.96297, index="4100/index-4108.fits"
# 2025-11-03 16:38:19,851 [INFO] solve 1: logodds=223.956, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9683, scale=2.96347, index="4100/index-4108.fits"
# 2025-11-03 16:38:19,853 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:20,002 [INFO] solve 1: logodds=293.711, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9707, scale=2.9625, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,152 [INFO] solve 1: logodds=293.685, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9707, scale=2.96263, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,302 [INFO] solve 1: logodds=292.882, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9708, scale=2.96306, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,455 [INFO] solve 1: logodds=266.123, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9691, scale=2.96399, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,604 [INFO] solve 1: logodds=275.788, matches=42, conflicts=0, distractors=4, ra=270.192, dec=29.9709, scale=2.96507, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,756 [INFO] solve 1: logodds=276.396, matches=42, conflicts=0, distractors=4, ra=270.191, dec=29.9693, scale=2.96337, index="4100/index-4109.fits"
# 2025-11-03 16:38:20,907 [INFO] solve 1: logodds=279.962, matches=42, conflicts=0, distractors=4, ra=270.193, dec=29.9695, scale=2.96448, index="4100/index-4109.fits"
# 2025-11-03 16:38:21,073 [INFO] solve 1: logodds=263.345, matches=42, conflicts=0, distractors=4, ra=270.193, dec=29.9684, scale=2.9638, index="4100/index-4109.fits"
# 2025-11-03 16:38:21,285 [INFO] WCS match: RA=270.19458, DEC=29.97071, scale=2.963
# 2025-11-03 16:38:21,285 [INFO] WCS match: RA=270.19458, DEC=29.97071, scale=2.963
# 2025-11-03 16:38:21,310 [INFO] WCS updated: longexp_001_20250719071333.wcs.fits
# 2025-11-03 16:38:21,310 [INFO] WCS updated: longexp_001_20250719071333.wcs.fits
# 2025-11-03 16:38:21,387 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/longexp_001_20250719071333.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:25,625 [INFO] loaded 3 index files
# 2025-11-03 16:38:25,626 [INFO] solve 1: start
# 2025-11-03 16:38:25,627 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:25,784 [INFO] solve 1: logodds=239.025, matches=42, conflicts=0, distractors=4, ra=270.197, dec=29.9812, scale=2.96289, index="4100/index-4108.fits"
# 2025-11-03 16:38:25,950 [INFO] solve 1: logodds=223.999, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9776, scale=2.9634, index="4100/index-4108.fits"
# 2025-11-03 16:38:26,111 [INFO] solve 1: logodds=223.739, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9785, scale=2.9636, index="4100/index-4108.fits"
# 2025-11-03 16:38:26,112 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:26,264 [INFO] solve 1: logodds=285.541, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9801, scale=2.96239, index="4100/index-4109.fits"
# 2025-11-03 16:38:26,417 [INFO] solve 1: logodds=285.508, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.98, scale=2.96253, index="4100/index-4109.fits"
# 2025-11-03 16:38:26,568 [INFO] solve 1: logodds=284.689, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9802, scale=2.96298, index="4100/index-4109.fits"
# 2025-11-03 16:38:26,721 [INFO] solve 1: logodds=259.435, matches=41, conflicts=0, distractors=5, ra=270.195, dec=29.9784, scale=2.96393, index="4100/index-4109.fits"
# 2025-11-03 16:38:26,875 [INFO] solve 1: logodds=268.943, matches=41, conflicts=0, distractors=5, ra=270.193, dec=29.9802, scale=2.96503, index="4100/index-4109.fits"
# 2025-11-03 16:38:27,027 [INFO] solve 1: logodds=269.23, matches=41, conflicts=0, distractors=5, ra=270.192, dec=29.9786, scale=2.9633, index="4100/index-4109.fits"
# 2025-11-03 16:38:27,180 [INFO] solve 1: logodds=273.021, matches=41, conflicts=0, distractors=5, ra=270.193, dec=29.9788, scale=2.96443, index="4100/index-4109.fits"
# 2025-11-03 16:38:27,384 [INFO] WCS match: RA=270.19473, DEC=29.98006, scale=2.962
# 2025-11-03 16:38:27,384 [INFO] WCS match: RA=270.19473, DEC=29.98006, scale=2.962
# 2025-11-03 16:38:27,413 [INFO] WCS updated: longexp_002_20250719070523.wcs.fits
# 2025-11-03 16:38:27,413 [INFO] WCS updated: longexp_002_20250719070523.wcs.fits
# 2025-11-03 16:38:27,500 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/longexp_002_20250719070523.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:32,162 [INFO] loaded 3 index files
# 2025-11-03 16:38:32,163 [INFO] solve 1: start
# 2025-11-03 16:38:32,164 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:32,328 [INFO] solve 1: logodds=240.219, matches=42, conflicts=0, distractors=4, ra=270.197, dec=29.972, scale=2.96295, index="4100/index-4108.fits"
# 2025-11-03 16:38:32,488 [INFO] solve 1: logodds=223.983, matches=42, conflicts=0, distractors=4, ra=270.196, dec=29.9683, scale=2.96347, index="4100/index-4108.fits"
# 2025-11-03 16:38:32,646 [INFO] solve 1: logodds=223.672, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9692, scale=2.96366, index="4100/index-4108.fits"
# 2025-11-03 16:38:32,648 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:32,800 [INFO] solve 1: logodds=293.743, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9708, scale=2.96249, index="4100/index-4109.fits"
# 2025-11-03 16:38:32,952 [INFO] solve 1: logodds=293.715, matches=42, conflicts=0, distractors=4, ra=270.194, dec=29.9708, scale=2.96262, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,105 [INFO] solve 1: logodds=292.897, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.971, scale=2.96306, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,257 [INFO] solve 1: logodds=266.157, matches=42, conflicts=0, distractors=4, ra=270.195, dec=29.9691, scale=2.96398, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,409 [INFO] solve 1: logodds=275.821, matches=42, conflicts=0, distractors=4, ra=270.192, dec=29.9709, scale=2.96504, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,560 [INFO] solve 1: logodds=276.397, matches=42, conflicts=0, distractors=4, ra=270.191, dec=29.9692, scale=2.96337, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,713 [INFO] solve 1: logodds=279.992, matches=42, conflicts=0, distractors=4, ra=270.193, dec=29.9695, scale=2.96446, index="4100/index-4109.fits"
# 2025-11-03 16:38:33,912 [INFO] WCS match: RA=270.19453, DEC=29.97083, scale=2.962
# 2025-11-03 16:38:33,912 [INFO] WCS match: RA=270.19453, DEC=29.97083, scale=2.962
# 2025-11-03 16:38:33,938 [INFO] WCS updated: longexp_003_20250719070825.wcs.fits
# 2025-11-03 16:38:33,938 [INFO] WCS updated: longexp_003_20250719070825.wcs.fits
# 2025-11-03 16:38:34,006 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/longexp_003_20250719070825.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:35,252 [INFO] loaded 3 index files
# 2025-11-03 16:38:35,253 [INFO] solve 1: start
# 2025-11-03 16:38:35,253 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:35,254 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:35,406 [INFO] solve 1: logodds=269.943, matches=39, conflicts=0, distractors=7, ra=236.598, dec=65.234, scale=2.9642, index="4100/index-4109.fits"
# 2025-11-03 16:38:35,556 [INFO] solve 1: logodds=268.25, matches=40, conflicts=0, distractors=6, ra=236.599, dec=65.2327, scale=2.96562, index="4100/index-4109.fits"
# 2025-11-03 16:38:35,706 [INFO] solve 1: logodds=269.444, matches=40, conflicts=0, distractors=6, ra=236.6, dec=65.2321, scale=2.96557, index="4100/index-4109.fits"
# 2025-11-03 16:38:35,858 [INFO] solve 1: logodds=265.796, matches=39, conflicts=0, distractors=7, ra=236.598, dec=65.234, scale=2.96383, index="4100/index-4109.fits"
# 2025-11-03 16:38:36,010 [INFO] solve 1: logodds=250.307, matches=39, conflicts=0, distractors=7, ra=236.598, dec=65.2334, scale=2.96426, index="4100/index-4109.fits"
# 2025-11-03 16:38:36,161 [INFO] solve 1: logodds=275.929, matches=39, conflicts=0, distractors=7, ra=236.597, dec=65.2347, scale=2.96293, index="4100/index-4109.fits"
# 2025-11-03 16:38:36,314 [INFO] solve 1: logodds=276.076, matches=39, conflicts=0, distractors=7, ra=236.598, dec=65.2347, scale=2.96307, index="4100/index-4109.fits"
# 2025-11-03 16:38:36,466 [INFO] solve 1: logodds=275.848, matches=39, conflicts=0, distractors=7, ra=236.597, dec=65.2347, scale=2.96279, index="4100/index-4109.fits"
# 2025-11-03 16:38:36,467 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4110.fits" (3 / 3)
# 2025-11-03 16:38:36,616 [INFO] solve 1: logodds=295.83, matches=38, conflicts=0, distractors=8, ra=236.594, dec=65.2348, scale=2.96727, index="4100/index-4110.fits"
# 2025-11-03 16:38:36,765 [INFO] solve 1: logodds=307.721, matches=39, conflicts=0, distractors=7, ra=236.6, dec=65.234, scale=2.9671, index="4100/index-4110.fits"
# 2025-11-03 16:38:36,822 [INFO] WCS match: RA=236.60010, DEC=65.23397, scale=2.967
# 2025-11-03 16:38:36,822 [INFO] WCS match: RA=236.60010, DEC=65.23397, scale=2.967
# 2025-11-03 16:38:36,846 [INFO] WCS updated: skyflat_001_20250719072515.wcs.fits
# 2025-11-03 16:38:36,846 [INFO] WCS updated: skyflat_001_20250719072515.wcs.fits
# 2025-11-03 16:38:36,905 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/skyflat_001_20250719072515.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:38,467 [INFO] loaded 3 index files
# 2025-11-03 16:38:38,468 [INFO] solve 1: start
# 2025-11-03 16:38:38,469 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:38,470 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:38,471 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4110.fits" (3 / 3)
# 2025-11-03 16:38:38,472 [INFO] solve 1: slice=[25, 50) (2 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:38,473 [INFO] solve 1: slice=[25, 50) (2 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:38,474 [INFO] solve 1: slice=[25, 50) (2 / 2), index="4100/index-4110.fits" (3 / 3)
# 2025-11-03 16:38:38,478 [WARNING] No WCS solution found for skyflat_001_20250719073146.fits.
# 2025-11-03 16:38:38,478 [WARNING] No WCS solution found for skyflat_001_20250719073146.fits.
# 2025-11-03 16:38:38,479 [WARNING] Skipping center coord calculation for skyflat_001_20250719073146.fits (no WCS).
# 2025-11-03 16:38:38,479 [WARNING] Skipping center coord calculation for skyflat_001_20250719073146.fits (no WCS).
# 2025-11-03 16:38:38,497 [INFO] WCS updated: skyflat_001_20250719073146.wcs.fits
# 2025-11-03 16:38:38,497 [INFO] WCS updated: skyflat_001_20250719073146.wcs.fits
# 2025-11-03 16:38:38,554 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/skyflat_001_20250719073146.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# 2025-11-03 16:38:41,623 [INFO] loaded 3 index files
# 2025-11-03 16:38:41,624 [INFO] solve 1: start
# 2025-11-03 16:38:41,625 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4108.fits" (1 / 3)
# 2025-11-03 16:38:41,626 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4109.fits" (2 / 3)
# 2025-11-03 16:38:41,779 [INFO] solve 1: logodds=281.264, matches=43, conflicts=0, distractors=3, ra=270.125, dec=39.941, scale=2.9641, index="4100/index-4109.fits"
# 2025-11-03 16:38:41,935 [INFO] solve 1: logodds=285.128, matches=42, conflicts=0, distractors=4, ra=270.126, dec=39.9412, scale=2.9633, index="4100/index-4109.fits"
# 2025-11-03 16:38:42,087 [INFO] solve 1: logodds=272.733, matches=44, conflicts=0, distractors=2, ra=270.125, dec=39.9381, scale=2.97291, index="4100/index-4109.fits"
# 2025-11-03 16:38:42,089 [INFO] solve 1: slice=[0, 25) (1 / 2), index="4100/index-4110.fits" (3 / 3)
# 2025-11-03 16:38:42,237 [INFO] solve 1: logodds=324.462, matches=43, conflicts=0, distractors=3, ra=270.128, dec=39.9371, scale=2.96616, index="4100/index-4110.fits"
# 2025-11-03 16:38:42,398 [INFO] solve 1: logodds=332.377, matches=42, conflicts=0, distractors=4, ra=270.124, dec=39.941, scale=2.96615, index="4100/index-4110.fits"
# 2025-11-03 16:38:42,545 [INFO] solve 1: logodds=330.035, matches=42, conflicts=0, distractors=4, ra=270.125, dec=39.94, scale=2.96852, index="4100/index-4110.fits"
# 2025-11-03 16:38:42,697 [INFO] solve 1: logodds=332.145, matches=42, conflicts=0, distractors=4, ra=270.124, dec=39.94, scale=2.96536, index="4100/index-4110.fits"
# 2025-11-03 16:38:42,849 [INFO] solve 1: logodds=327.522, matches=42, conflicts=0, distractors=4, ra=270.125, dec=39.9407, scale=2.96537, index="4100/index-4110.fits"
# 2025-11-03 16:38:42,997 [INFO] solve 1: logodds=328.186, matches=42, conflicts=0, distractors=4, ra=270.125, dec=39.9404, scale=2.96634, index="4100/index-4110.fits"
# 2025-11-03 16:38:43,146 [INFO] solve 1: logodds=336.519, matches=42, conflicts=0, distractors=4, ra=270.126, dec=39.9411, scale=2.96288, index="4100/index-4110.fits"
# 2025-11-03 16:38:43,214 [INFO] WCS match: RA=270.12558, DEC=39.94111, scale=2.963
# 2025-11-03 16:38:43,214 [INFO] WCS match: RA=270.12558, DEC=39.94111, scale=2.963
# 2025-11-03 16:38:43,240 [INFO] WCS updated: skyflat_001_20250719074006.wcs.fits
# 2025-11-03 16:38:43,240 [INFO] WCS updated: skyflat_001_20250719074006.wcs.fits
# 2025-11-03 16:38:43,305 [INFO] using the unit adu passed to the FITS reader instead of the unit adu in the FITS file.
# ../solo-data/tmp/skyflat_001_20250719074006.wcs.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 if science_frames:
#       5     for fpath_sci in science_frames:
# ----> 6         fpath_wcs = lv1.update_wcs(fpath_sci, TMPDIR, return_fpath=True)
#       7         print(fpath_wcs)
#
# File ~/Desktop/solopy/solopy/Lv1.py:61, in Lv1.update_wcs(self, fpath_fits, outdir, return_fpath)
#      59 try:
#      60     bkg = sep.Background(sci.data)
# ---> 61     objs = sep.extract(sci.data - bkg.back(), thresh=3.0 * bkg.globalrms, minarea=5)
#      62     bright = objs[np.argsort(objs['flux'])[::-1][:50]]
#      63     coords = np.vstack((bright['x'], bright['y'])).T
#
# KeyboardInterrupt:

# %%
# Master bias
bias_files = all_lv0_fits.files_filtered(IMAGETYP="BIAS", include_path=True)
if bias_files:
    comb.make_mbias(bias_files, MASTERDIR)
    
# Master dark
dark_files = all_lv0_fits.files_filtered(IMAGETYP="DARK", include_path=True)
if dark_files:
    comb.make_mdark(dark_files, MASTERDIR, key_exptime='EXPTIME')
